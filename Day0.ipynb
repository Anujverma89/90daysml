# %% [markdown]
# # **RECAP OF MY MACHINE LEARNING KNOWLEDGE**

# %% [markdown]
# # Exploring AI as unbrella term :
# * AI is umbrella term that refers to intelligent Machines(Systems).
# * Artificial intelligence can be achieved using many approaches like
#     * Symboli AI / Knowledge based learning
#       * Fuzzy logic etc
#       * Rule based system.
#     * Machine Learning/ Statistical Learning ( Extracting pattern from data)
#       * Supervised
#       * Unsupervised
#       * Semi-Supervised
#       * Reinforcement Leaning
#     * Deep learning
#       * ANN
#       * CNN
#       * RNN
#       * LSTM
#       * Autoencoders
#       * Transformers
#     * Gen AI - Built on top of Deep learning using architectures like transformers, autoencoders.

# %% [markdown]
# # Uses of Mathematics in machine learning :
# * Vector : Used to organize data. Almost in every scenerio features are represented in terms of vectors.
# * Differential calculus : Used for minimization of loss function using using gradient descent or back propagation method.
# * Matrix multiplication (Linear Algebra) : Used for feedforward mechanism in Nerural network.
# * Probability & Statistics : Used in probabilistic algorithms, proprocessing of data and data visualisation, etc.

# %% [markdown]
# # Exploring different functions in machine learning :
# * Loss function / Cost function : Used to compute the loss.
# * Optimization function : Used to minimize the loss function.
# * Activation function : Used to transform the output into desired form.

# %% [markdown]
# # Types of Loss functions in machine learning :
# * **Regression**
#   * MSE (Means squared error)
#   * RMSE (Root mean squared error)
#   * MAE (Mean absolute error)
# * **Classification**
#   * Classification error
#   * Misclassification rate
#   * Confusion Matrix
#   * Log Loss
#   * Hinge Loss
#   * Brier Loss
#   * Flase positive / False negative
# * **Clustering**
#   * Inertia (Within-Cluster SSE)
#   * Silhouette Score
#   * Cluster purity
#   * Davies-Bouldin Index
#   * Adjusted Random Index
#   * Normalized mutual information
# * **Reinforcement Learning**
#   * Temporal Difference

# %% [markdown]
# # Types of Activation function :
# * **Activation functions are used to transform the output into the desired format**
#   * **Linear (No changes)** F(x) = x
#   * **Non Linear**
#     * Sigmoid
#     * Tanh (Hyperbolic Tangant)
#     * ReLU (Rectified Linear Unit)
#     * Leaky ReLU
#     * Parametric ReLU (PReLU)
#     * ELU (Exponential Linear Unit)
#     * Softmax (Used for multi-class classification)
#   * **Others**
#     * Swish
#     * Mish
#     * GELU (Gaussian Error Linear Unit)

# %% [markdown]
# # Types of Optimization (Optimizers)  function :
# * **First Order Optimizers**
#   * Gradient Descent
#   * Stocashtic Gradient Descent
#   * Mini Batch Gradient Descnet
#   * Momentum
#   * Nastrov Accelerated Gradient (NAG)
# * **Adaptive Optimization Method**(They adjust their learning rate dynamically)
#   * Adagrad
#   * Adam(Adaptive moment estimation)
#   * Nadam
#   * Adamax
#   * RMSprop
# * **Second Order**
#   * Newton's method
#   * L-BFGS
#   * Conjugate Gradient
# * **Global Optimization**
#   * Genetic algorithms
#   * Simmulated Annealing
#   * Particle Swarm optimization
#   * Bayesian Optimization

# %% [markdown]
# # Matrics to evaluate machine learning models :
# * Accuracy
# * Confusion Matrix
# * F1 score
# * Precision
# * Recall
# * False Positive (Type 1 Error)
# * False Negative (Type 2 Error)
# * Log Loss
# * RUC-AUC curve
# * R2 score
# * Silhouette Score
# * Davies–Bouldin Index
# * Adjusted Rand Index
# * Homogeneity / Completeness
# * Precision@k
# * Recall@k
# * MAP (Mean Average Precision)
# * NDCG (Normalized Discounted Cumulative Gain)
# * Cumulative Reward
# * Average Episode Length
# * Success Rate
# * TD Error
# * OOB Score (Out of bag Score)

# %% [markdown]
# # Bias Variance Trade-off
# * High variance leads to overfitting
# * High bias leads to underfitting
# * **We as a machine learning engineer have to take care of balancing both bias and variance such that models gives otimumum result**

# %% [markdown]
# # Model Optimization Techniques
# * Hyperparameter Tuning (adjusting no of nuerons, Layers, Learning rate, etc.)
# * Data processing
# * Ensemble learning
# * Regularization
# * Choose complex model (In case of underfitting), etc.

# %% [markdown]
# # End to End Machine Learning Pipeline :
# * Identify Problem.
# * Gather data.
# * Prprocess and convert data into disered format.
# * Feed data to Machine Learning Algorithm (When algorithm is trained over data it becomes a machine learning model).
# * Test the Model against the testing dataset.
# * In case of unsatisfactory results tweak some hyperparameters
# * Retrain the model.
# * Deploy the model.
# * **Machine learning model in nothing but a collection of weight's and biases learned from training data along with mathematical function**

# %% [markdown]
# # Deploying machine learning model with django or any other python based framework
# * Simply export the trained model.(model gets saved in form of file with extension like .h5 depending on the framework used for traning the model)
# * Load the exported file in any of the framework using pickle or some other libraries
# * Feed the input in the same format as the input format used while training the model else will produce error.
# * Predict the output and server the output as a httpresponse() or jsonresponse()
#
# ### We can use MLops for continious training and deployment in case of data drift OR when large amount of data is produced on regular interval.

# %% [markdown]
# # Exploring differrent in machine learning algorithms :

# %%
import matplotlib.pyplot as plt
from PIL import Image 
import numpy as np

# %%
img = Image.open("./algorithm_cheatSheet.png")
imgarray = np.array(img)

plt.figure(figsize=(20, 12)) 
plt.imshow(imgarray)
plt.axis('off')
plt.show()

# %%
img = Image.open("./macineLearning_algorithm_cheetsheets.png")
imgarray = np.array(img)

plt.figure(figsize=(20, 12)) 
plt.imshow(imgarray)
plt.axis('off')
plt.show()

# %% [markdown]
# # What does it means when we say that we are training a model ?
# * Bascially when we train model we are trying to understand the pattern from data in the form of weights and biases.
# * Those weights and biases can be transfered and here comes the concept of transfer learning.
