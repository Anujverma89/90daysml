# %% [markdown]
# # 1. Search Algorithms
# ## 1.1 Uninformed (Blind) Search
# * Breadth-First Search (BFS)
# * Depth-First Search (DFS)
# * Depth-Limited Search
# * Iterative Deepening DFS
# * Uniform Cost Search
#
# ## 1.2 Informed (Heuristic) Search
# * A* Search
# * Greedy Best-First Search
# * Beam Search
# * Hill Climbing (Simple, Stochastic, First-choice)
# * Iterative Improvement
#
# # 2. Knowledge Representation and Reasoning
# ## 2.1 Logic-Based
# * Propositional Logic Inference
# * First-Order Logic Inference (Resolution, Unification)
# * Forward Chaining
# * Backward Chaining
#
# ## 2.2 Probabilistic Reasoning
# * Bayesian Networks
# * Hidden Markov Models (HMM)
# * Markov Decision Processes (MDP)
# * Conditional Random Fields (CRF)
#
# # 3. Machine Learning
# ## 3.1 Supervised Learning
# ### 3.1.1 Regression
# * Linear Regression
# * Polynomial Regression
# * Ridge & Lasso Regression
#
# ## 3.1.2 Classification
# * Logistic Regression
# * k-Nearest Neighbors (k-NN)
# * Support Vector Machines (SVM)
# * Decision Trees
# * Random Forest
# * Naive Bayes
# * Gradient Boosting (XGBoost, LightGBM, CatBoost)
# * Neural Networks (ANN, CNN, RNN)
#
# ## 3.2 Unsupervised Learning
# * k-Means Clustering
# * Hierarchical Clustering
# * DBSCAN
# * Principal Component Analysis (PCA)
# * Independent Component Analysis (ICA)
# * Autoencoders
#
# ## 3.3 Semi-Supervised Learning
# * Label Propagation
# * Self-Training
# * Co-Training
#
# ## 3.4 Reinforcement Learning
# * Q-Learning
# * Deep Q-Networks (DQN)
# * SARSA
# * Policy Gradient Methods
# * Actor-Critic Algorithms
# * Proximal Policy Optimization (PPO)
# * Deep Deterministic Policy Gradient (DDPG)
#
# # 4. Natural Language Processing (NLP)
# * Rule-Based Parsing
# * Statistical NLP (n-gram models, HMMs)
# * Word Embeddings (Word2Vec, GloVe, FastText)
# * Transformer Models (BERT, GPT, RoBERTa, T5)
# * Seq2Seq Models
# * Attention Mechanism
# * Named Entity Recognition (NER)
# * Part-of-Speech Tagging (POS)
# * Sentiment Analysis Algorithms
#
# # 5. Computer Vision
# * Convolutional Neural Networks (CNN)
# * Object Detection (YOLO, SSD, R-CNN, Fast/Faster R-CNN)
# * Semantic Segmentation (U-Net, Mask R-CNN)
# * Optical Flow Algorithms (Lucas-Kanade, Horn-Schunck)
# * Feature Matching (SIFT, SURF, ORB)
#
# # 6. Optimization Algorithms
# * Gradient Descent
# * Stochastic Gradient Descent (SGD)
# * Adam, RMSProp, Adagrad
# * Genetic Algorithms
# * Simulated Annealing
# * Particle Swarm Optimization
# * Ant Colony Optimization
#
# # 7. Fuzzy Logic & Expert Systems
# * Fuzzy Inference Systems (Mamdani, Sugeno)
# * Rule-Based Expert Systems
#
# # 8. Evolutionary & Bio-inspired Algorithms
# * Genetic Algorithms
# * Genetic Programming
# * Evolution Strategies
# * Swarm Intelligence
# * Artificial Bee Colony
# * Artificial Immune Systems
#
# # 9. Ensemble Methods
# * Bagging (e.g., Random Forest)
# * Boosting (e.g., AdaBoost, Gradient Boosting)
# * Stacking
