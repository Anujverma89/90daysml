# %% [markdown]
# # Maths Refresher
# ### **Vector Calculus**

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
img = Image.open("./vector_calc.png")
imgarr = np.array(img)
plt.figure(figsize=(20,12))
plt.axis("Off")
plt.imshow(imgarr)

# %% [markdown]
# # Function :
# * A relation that maps input to an output.
# * domain = All input function can take.
# * codomain, image = All optput produced by function.
#
# ### Mapping : (input to ouput)
# * tells about the mapping between input and output
# * One to one
# * One to many
# * Many to one
# * Many to Many
